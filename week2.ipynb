# %% [markdown]
# ## Week 2

# %%
import seaborn as sns
import pandas as pd 
import matplotlib.pyplot as plt

survey = pd.read_csv('survey.csv')
steps = pd.read_csv('steps.csv', sep=';')
survey.head()
# Out:
#    id         city  gender    age  hh_size  education          education_1  \
# 0   1     Bordeaux    Male  25-34        4          4  Master or doctorate
# 1   2        Lille    Male  35-44        1          3             Bachelor
# 2   3  Montpellier    Male  25-34        2          2  Master or doctorate
# 3   4         Lyon    Male    <25        1          1             Bachelor
# 4   5  Montpellier  Female  25-34        3          4             Bachelor
#
#    height  weight
# 0   178.0    98.0
# 1   180.0    77.0
# 2   180.0    83.0
# 3   178.0    80.0
# 4   167.0    61.0

# %%
steps.head()
# Out:
#    id  20-6-2013  21-6-2013  22-6-2013  23-6-2013  24-6-2013  25-6-2013  \
# 0   1        NaN        NaN        NaN        NaN     3941.0    15733.0
# 1   2        NaN        NaN    10473.0      705.0     4287.0     5507.0
# 2   3        NaN    11428.0    12523.0     2553.0      190.0     2164.0
# 3   4        NaN        NaN        NaN        NaN        NaN        NaN
# 4   5        NaN        NaN        NaN        NaN        NaN        NaN
#
#    26-6-2013  27-6-2013  28-6-2013  ...  4-5-2014  5-5-2014  6-5-2014  \
# 0     9929.0    12879.0    10541.0  ...       NaN       NaN       NaN
# 1     4024.0     3926.0    14595.0  ...       NaN       NaN       NaN
# 2     8185.0     9630.0     8983.0  ...    3914.0    4364.0       NaN
# 3        NaN        NaN        NaN  ...       NaN       NaN       NaN
# 4        NaN        NaN        NaN  ...       NaN       NaN       NaN
#
#    7-5-2014  8-5-2014  9-5-2014  10-5-2014  11-5-2014  12-5-2014  13-5-2014
# ...

# %% [markdown]
# # Create the variable mean steps per participant

# %%
mean_steps = df.loc[:, "20-6-2013":"13-5-2014"].mean(axis=1)
mean_steps.index
mean_steps.head()
steps['mean_steps'] = mean_steps # New data frame
steps.head()
# Out:
#    id  20-6-2013  21-6-2013  22-6-2013  23-6-2013  24-6-2013  25-6-2013  \
# 0   1        NaN        NaN        NaN        NaN     3941.0    15733.0
# 1   2        NaN        NaN    10473.0      705.0     4287.0     5507.0
# 2   3        NaN    11428.0    12523.0     2553.0      190.0     2164.0
# 3   4        NaN        NaN        NaN        NaN        NaN        NaN
# 4   5        NaN        NaN        NaN        NaN        NaN        NaN
#
#    26-6-2013  27-6-2013  28-6-2013  ...  5-5-2014  6-5-2014  7-5-2014  \
# 0     9929.0    12879.0    10541.0  ...       NaN       NaN       NaN
# 1     4024.0     3926.0    14595.0  ...       NaN       NaN       NaN
# 2     8185.0     9630.0     8983.0  ...    4364.0       NaN       NaN
# 3        NaN        NaN        NaN  ...       NaN       NaN       NaN
# 4        NaN        NaN        NaN  ...       NaN       NaN       NaN
#
#    8-5-2014  9-5-2014  10-5-2014  11-5-2014  12-5-2014  13-5-2014  \
# ...

# %% [markdown]
# Merge data sets

# %%
df = pd.merge(survey, steps, on = 'id')
df.head()
# Out:
#    id         city  gender    age  hh_size  education          education_1  \
# 0   1     Bordeaux    Male  25-34        4          4  Master or doctorate
# 1   2        Lille    Male  35-44        1          3             Bachelor
# 2   3  Montpellier    Male  25-34        2          2  Master or doctorate
# 3   4         Lyon    Male    <25        1          1             Bachelor
# 4   5  Montpellier  Female  25-34        3          4             Bachelor
#
#    height  weight  20-6-2013  ...  5-5-2014  6-5-2014  7-5-2014  8-5-2014  \
# 0   178.0    98.0        NaN  ...       NaN       NaN       NaN       NaN
# 1   180.0    77.0        NaN  ...       NaN       NaN       NaN       NaN
# 2   180.0    83.0        NaN  ...    4364.0       NaN       NaN       NaN
# 3   178.0    80.0        NaN  ...       NaN       NaN       NaN       NaN
# 4   167.0    61.0        NaN  ...       NaN       NaN       NaN       NaN
#
#    9-5-2014  10-5-2014  11-5-2014  12-5-2014  13-5-2014    mean_steps
# ...

# %%
df.fillna(0)
# Out:
#       id         city  gender    age  hh_size  education          education_1  \
# 0      1     Bordeaux    Male  25-34        4          4  Master or doctorate
# 1      2        Lille    Male  35-44        1          3             Bachelor
# 2      3  Montpellier    Male  25-34        2          2  Master or doctorate
# 3      4         Lyon    Male    <25        1          1             Bachelor
# 4      5  Montpellier  Female  25-34        3          4             Bachelor
# 5      6        Lille    Male  35-44        1          1           Vocational
# 6      7  Montpellier    Male  25-34        2          2  Master or doctorate
# 7      8     Bordeaux  Female  25-34        3          4  Master or doctorate
# 8      9        Lille  Female  35-44        4          4           Vocational
# 9     10        Lille  Female  25-34        2          2  Master or doctorate
# 10    11     Bordeaux  Female    <25        2          2             Bachelor
# ...

# %%
# Remove data with < 60000 steps 

def above_60000(x):
    if(x > 60000.0): 
        return float('NaN')
    else: 
        return x
df['mean_steps'] = df['mean_steps'].apply(above_60000)

df.head()
# Out:
#    id         city  gender    age  hh_size  education          education_1  \
# 0   1     Bordeaux    Male  25-34        4          4  Master or doctorate
# 1   2        Lille    Male  35-44        1          3             Bachelor
# 2   3  Montpellier    Male  25-34        2          2  Master or doctorate
# 3   4         Lyon    Male    <25        1          1             Bachelor
# 4   5  Montpellier  Female  25-34        3          4             Bachelor
#
#    height  weight  20-6-2013  ...  5-5-2014  6-5-2014  7-5-2014  8-5-2014  \
# 0   178.0    98.0        NaN  ...       NaN       NaN       NaN       NaN
# 1   180.0    77.0        NaN  ...       NaN       NaN       NaN       NaN
# 2   180.0    83.0        NaN  ...    4364.0       NaN       NaN       NaN
# 3   178.0    80.0        NaN  ...       NaN       NaN       NaN       NaN
# 4   167.0    61.0        NaN  ...       NaN       NaN       NaN       NaN
#
#    9-5-2014  10-5-2014  11-5-2014  12-5-2014  13-5-2014    mean_steps
# ...

# %% [markdown]
# # Mean of steps per person

# %%
df.fillna(0)
# Out:
#       id         city  gender    age  hh_size  education          education_1  \
# 0      1     Bordeaux    Male  25-34        4          4  Master or doctorate
# 1      2        Lille    Male  35-44        1          3             Bachelor
# 2      3  Montpellier    Male  25-34        2          2  Master or doctorate
# 3      4         Lyon    Male    <25        1          1             Bachelor
# 4      5  Montpellier  Female  25-34        3          4             Bachelor
# 5      6        Lille    Male  35-44        1          1           Vocational
# 6      7  Montpellier    Male  25-34        2          2  Master or doctorate
# 7      8     Bordeaux  Female  25-34        3          4  Master or doctorate
# 8      9        Lille  Female  35-44        4          4           Vocational
# 9     10        Lille  Female  25-34        2          2  Master or doctorate
# 10    11     Bordeaux  Female    <25        2          2             Bachelor
# ...

# %%
variables = df[['mean_steps', 'height', 'weight']]
print(variables)
# Out:
#        mean_steps  height  weight
# 0    10205.521212   178.0    98.0
# 1     5687.423313   180.0    77.0
# 2     8301.729730   180.0    83.0
# 3     3633.200000   178.0    80.0
# 4     5312.129630   167.0    61.0
# 5    11908.509804   170.0    63.0
# 6     4715.400000   175.0    75.0
# 7     3594.051724   165.0    88.0
# 8     8626.707965   172.0    69.0
# 9     3787.043478   165.0    93.0
# 10    6626.909836   169.0    61.0
# 11    1303.611111   162.0    60.0
# 12    5622.133333   176.0    75.0
# 13    9214.798077   170.0    83.0
# 14    2664.461538   158.0    50.0
# 15    9994.432692   182.0    68.0
# 16    9791.608696   174.0    68.0
# 17            NaN   170.0    83.0
# 18    4696.526316   179.0    60.0
# 19   10587.986577   160.0    54.0
# 20    6235.238095   186.0    95.0
# 21    5667.045977   170.0    73.0
# 22    6769.695652   175.0    70.0
# 23    3885.000000   183.0    78.0
# 24    3021.181818   166.0    73.0
# 25   12565.815789   185.0   140.0
# ...

# %%
df['weight'].dropna()
df['height'].dropna()
df['mean_steps'].dropna()
# Out:
# 0      10205.521212
# 1       5687.423313
# 2       8301.729730
# 3       3633.200000
# 4       5312.129630
# 5      11908.509804
# 6       4715.400000
# 7       3594.051724
# 8       8626.707965
# 9       3787.043478
# 10      6626.909836
# 11      1303.611111
# 12      5622.133333
# 13      9214.798077
# 14      2664.461538
# 15      9994.432692
# 16      9791.608696
# 18      4696.526316
# 19     10587.986577
# 20      6235.238095
# 21      5667.045977
# 22      6769.695652
# 23      3885.000000
# 24      3021.181818
# 25     12565.815789
# 26      6330.031250
# 27      7969.027586
# 28      4745.200000
# 29      5525.080460
# 30      1218.500000
#            ...
# 899     1832.142857
# 900     6638.747475
# 901     4099.833333
# 902    10817.741935
# 903     6281.930818
# 904     6729.168539
# 905     9472.562500
# 906     4285.759259
# 907    15743.724739
# 908     5968.338462
# 909     7174.323944
# 910     1914.750000
# 911    13603.277344
# 912    10457.031447
# ...

# %%
# Correlation matrix

sns.pairplot(variables.dropna())
plt.show()

# %% [markdown]
# # Heat map

# %%
corr = df[['mean_steps', 'height', 'weight']].corr()
corr
# Out:
#             mean_steps    height    weight
# mean_steps    1.000000 -0.097515 -0.048404
# height       -0.097515  1.000000  0.265138
# weight       -0.048404  0.265138  1.000000

# %%
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns)
plt.show()

# %% [markdown]
# # Scatterplox

# %%
sns.scatterplot(data=df, x="weight", y="mean_steps")

# %%
sns.scatterplot(data=df, x="height", y="mean_steps")

# %% [markdown]
# # Pearson's correlation

# %%
# Weight combined with steps
weight = variables.drop(columns="height")
weight.corr()
# Out:
#             mean_steps    weight
# mean_steps    1.000000 -0.048404
# weight       -0.048404  1.000000

# %%
# Weight combined with steps
height = variables.drop(columns="weight")
height.corr()
# Out:
#             mean_steps    height
# mean_steps    1.000000 -0.097515
# height       -0.097515  1.000000

# %% [markdown]
# # Description
#
# The correlation between weight and the mean is -0.048404. That indicates a weak negative relationship.
# The correlation between height and steps is -0.097515, which also indicates a weak negative relationship.
# Correlation between weight and the mean of steps is weaker than correlation between height and the mean of steps.

# %% [markdown]
# # The relation of mean steps per participant with a qualitative variable
#
# The relation between city and mean of steps depicted on bar chart. It can be clearly seen that citizens of Lille walks the most.

# %%
sns.barplot(x="city", y="mean_steps", data=df)
plt.show()

# %% [markdown]
# # The relation of two qualitative variables

# %%
sns.countplot(x="city", hue="education_1", data=df)
plt.show()

# %%
pd.crosstab(df["city"], df["education_1"], normalize="columns") * 100
# Out:
# education_1   Bachelor  High school  Master or doctorate  No degree  \
# city
# Bordeaux     15.406162    17.924528            10.922330        0.0
# Lille        55.742297    60.377358            51.213592        0.0
# Lyon         12.324930    11.320755            18.932039      100.0
# Montpellier  16.526611    10.377358            18.932039        0.0
#
# education_1    Primary  Vocational
# city
# Bordeaux     15.384615        20.0
# Lille        53.846154        60.0
# Lyon         30.769231         7.5
# Montpellier   0.000000        12.5

# %% [markdown]
# # Description
#
# Graph depicts relation between citizens of different cities and their level of education.
# Most of people with higher education such as Bachelor, Master of doctorate degree lives in Lille.
